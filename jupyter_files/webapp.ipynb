# %%
# !pip install streamlit
import streamlit

# %%
# !pip install tensorflow
import tensorflow as tf

# %%
import numpy as np
import pandas as pd

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('../data/zillow_data.csv')
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# ...

# %%
[df.RegionID[0]]
# Out:
# [84654]

# %%
df_time_series = pd.DataFrame(data=np.ones(len(df.columns)-7))
for i in range(df.shape[0]):
    data = pd.DataFrame(np.array(df.iloc[i,7:]), columns=[df.RegionID[i]])
    df_time_series.join(df_time_series, lsuffix='_df_time_series', rsuffix='_data')
     #df_time_series.join(pd.DataFrame(np.array(df.iloc[i,7:]), columns=[df.RegionID[i]]), how='right')
#df_time_series.drop(df_time_series.columns[0],axis=1, inplace=True)
#df_time_series.index=pd.to_datetime(df.columns[7:])
#pd.DataFrame(np.array(df.iloc[0,7:]), columns=[df.RegionID[0]])

# %%
df_time_series
# Out:
#        0
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# ..   ...
# 260  1.0
# 261  1.0
# 262  1.0
# 263  1.0
# 264  1.0
#
# [265 rows x 1 columns]
